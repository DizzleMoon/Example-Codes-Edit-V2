# %%
import arcgis
from arcgis.gis import GIS
import pandas as pd
import datetime
import getpass
from IPython.display import HTML

from arcgis import geocoding
from arcgis.features import Feature, FeatureSet
from arcgis.features import GeoAccessor, GeoSeriesAccessor

# %%
api_key = "AAPKb924aa22a2c04a43948522166a50233aV7220htxh7Kf9oyEw8YQhKMjEE5pfZ5caL_2ApPUClsueGMtRw4eqirTDtPK0ofP"
#     api_key = "YOUR_API_KEY"
my_gis = arcgis.GIS("https://www.arcgis.com", api_key=api_key)

# api_key = "AAPK6815d252f60c4322aea51e58fd28be5ayfl7xP7lV_4qTMtEDBjaz_eSSWNtiIJJixWgXZBHSSROjs6Q883scxme54jS2T5Y"
# #     api_key = "YOUR_API_KEY"
# my_gis = arcgis.GIS("https://www.arcgis.com", api_key=api_key)

# %%
# origin_coords = ['-117.187807, 33.939479', '-117.117401, 34.029346']
# origin_features = []

# for origin in origin_coords:
#     print(origin)
# #     reverse_geocode = geocoding.reverse_geocode({"x": origin.split(',')[0], 
# #                                               "y": origin.split(',')[1]}) 

#     reverse_geocode = geocoding.reverse_geocode({"x": coord[0]['x'], 
#                                              "y": coord[0]['y']})
#     print(reverse_geocode)
#     print('\n')

#     origin_feature = Feature(geometry=reverse_geocode['location'], 
#                            attributes=reverse_geocode['address'])
#     origin_features.append(origin_feature)
    
# print(origin_features)
# print('\n')

# origin_fset = FeatureSet(origin_features, geometry_type='esriGeometryPoint',
#                           spatial_reference={'latestWkid': 4326})
# print(origin_fset)

# %%
addresses_item = my_gis.content.search('destinations_address', 'feature layer')[0]
addresses_item
# Out:
# <Item title:"Annual_Precip_2012" type:Feature Layer Collection owner:lbryant_nhedgis>

# %%
destinations_sdf = addresses_item.layers[0].query(as_df=True)
destinations_sdf
# Out:
#      FID  OBJECTID OBJECT_ID                Station_Na  Total_Prcp  \
# 0      1         1   NH-BK-1  Tilton Northfield 3.3 NE       47.46
# 1      2         2   NH-BK-2            Belmont 1.7 SW       47.34
# 2      3         3   NH-BK-5        New Hampton 5.3 NE       29.88
# 3      4         4   NH-BK-7             Laconia 7.9 E       47.17
# 4      5         5   NH-BK-9          Meredith 2.9 SSW       49.16
# ..   ...       ...       ...                       ...         ...
# 118  119       119   NH-SL-1         Plainfield 0.3 SW       31.39
# 119  120       120   NH-SL-2             Goshen 2.0 NE        9.16
# 120  121       121   NH-SL-3        West Unity 0.7 WSW       34.55
# 121  122       122   NH-SL-7             Unity 3.2 ENE       26.09
# 122  123       123   NH-SL-8             Sunapee 2.3 N       38.26
#
#      Days_Cover  Daily_Prcp  Daily_Obse  Multiday_P  Days_Cov_1  Multiday_R  \
# 0           356       45.74         342        1.72          14           5
# 1           366       47.34         366        0.00           0           0
# 2            84       29.88          84        0.00           0           0
# 3           344       45.68         337        1.49           7           3
# 4           364       47.09         353        2.07          11           3
# ..          ...         ...         ...         ...         ...         ...
# 118         343       23.34         281        8.05          62          11
# 119          33        9.16          33        0.00           0           0
# 120         362       34.55         362        0.00           0           0
# 121         187       22.56         176        3.53          11           4
# 122         367       26.25         298       12.01          69          19
#
#      Days_With  Days_Wit_1  Total_Snow  Days_Wit_2  Days_Wit_3   Latitude  \
# 0          125          18        54.3          23          70  43.480000
# 1          142          38        59.1          24          75  43.435562
# 2           65           3         0.0           0           0  43.647876
# 3          106          20        43.9          19           7  43.554149
# 4          140          24        55.2          23          72  43.622449
# ..         ...         ...         ...         ...         ...        ...
# 118         82          10        33.4          15          52  43.530325
# 119         24           1         0.0           0           0  43.314748
# 120        124          84        47.4          23          60  43.286517
# 121         59          23        20.5           6           0  43.316900
# 122         98          22        46.1          22           6  43.420129
#
#      Longitude  Elevation                                              SHAPE
# 0   -71.550000        680  {"x": -7964909.474918244, "y": 5385319.1230474...
# 1   -71.506874        702  {"x": -7960108.721342988, "y": 5378504.2357500...
# 2   -71.568201        664  {"x": -7966935.643622118, "y": 5411109.5689599...
# 3   -71.323108        564  {"x": -7939651.980886165, "y": 5396701.6072392...
# 4   -71.535087        677  {"x": -7963249.366946323, "y": 5407198.6218585...
# ..         ...        ...                                                ...
# 118 -72.359712        495  {"x": -8055046.161214717, "y": 5393042.8753068...
# 119 -72.113737       1291  {"x": -8027664.37115518, "y": 5360001.72410986...
# 120 -72.329717        905  {"x": -8051707.147086771, "y": 5355683.4923355...
# 121 -72.205100       1271  {"x": -8037834.850348912, "y": 5360330.9782417...
# 122 -72.090980       1373  {"x": -8025131.073530523, "y": 5376138.6213152...
#
# [123 rows x 20 columns]

# %%
destinations_sdf.columns
# Out:
# Index(['FID', 'OBJECTID', 'OBJECT_ID', 'Station_Na', 'Total_Prcp',
#        'Days_Cover', 'Daily_Prcp', 'Daily_Obse', 'Multiday_P', 'Days_Cov_1',
#        'Multiday_R', 'Days_With', 'Days_Wit_1', 'Total_Snow', 'Days_Wit_2',
#        'Days_Wit_3', 'Latitude', 'Longitude', 'Elevation', 'SHAPE'],
#       dtype='object')

# %%
len(destinations_sdf)
# Out:
# 123

# %%
dest = pd.DataFrame(destinations_sdf,columns=['OBJECTID','SHAPE'])
dest
# Out:
#      OBJECTID                                              SHAPE
# 0           1  {"x": -7964909.474918244, "y": 5385319.1230474...
# 1           2  {"x": -7960108.721342988, "y": 5378504.2357500...
# 2           3  {"x": -7966935.643622118, "y": 5411109.5689599...
# 3           4  {"x": -7939651.980886165, "y": 5396701.6072392...
# 4           5  {"x": -7963249.366946323, "y": 5407198.6218585...
# ..        ...                                                ...
# 118       119  {"x": -8055046.161214717, "y": 5393042.8753068...
# 119       120  {"x": -8027664.37115518, "y": 5360001.72410986...
# 120       121  {"x": -8051707.147086771, "y": 5355683.4923355...
# 121       122  {"x": -8037834.850348912, "y": 5360330.9782417...
# 122       123  {"x": -8025131.073530523, "y": 5376138.6213152...
#
# [123 rows x 2 columns]

# %%
origin_coords = ['-117.187807, 33.939479', '-117.117401, 34.029346']
origin_features = []

Lat = destinations_sdf['Latitude'][0:2]
Long = destinations_sdf['Longitude'][0:2]

for i in range(len(Lat)):
    reverse_geocode = geocoding.reverse_geocode({"x": Long[i], 
                                             "y": Lat[i]})
    origin_feature = Feature(geometry=reverse_geocode['location'], 
                           attributes=reverse_geocode['address'])
    origin_features.append(origin_feature)
    
origin_fset = FeatureSet(origin_features, geometry_type='esriGeometryPoint',
                          spatial_reference={'latestWkid': 4326})
print(origin_fset)   

# for origin in origin_coords:
#     print(origin)
# #     reverse_geocode = geocoding.reverse_geocode({"x": origin.split(',')[0], 
# #                                               "y": origin.split(',')[1]}) 

#     reverse_geocode = geocoding.reverse_geocode({"x": coord[0]['x'], 
#                                              "y": coord[0]['y']})
#     print(reverse_geocode)
#     print('\n')

#     origin_feature = Feature(geometry=reverse_geocode['location'], 
#                            attributes=reverse_geocode['address'])
#     origin_features.append(origin_feature)
    
# print(origin_features)
# print('\n')

# origin_fset = FeatureSet(origin_features, geometry_type='esriGeometryPoint',
#                           spatial_reference={'latestWkid': 4326})
# print(origin_fset)
# Out:
# {"features": [{"geometry": {"x": -71.55026815080141, "y": 43.48081594779246, "spatialReference": {"wkid": 4326, "latestWkid": 4326}}, "attributes": {"Match_addr": "225-227 Lancaster Hill Rd, Tilton, New Hampshire, 03276", "LongLabel": "225-227 Lancaster Hill Rd, Tilton, NH, 03276, USA", "ShortLabel": "225-227 Lancaster Hill Rd", "Addr_type": "StreetAddress", "Type": "", "PlaceName": "", "AddNum": "225", "Address": "225 Lancaster Hill Rd", "Block": "", "Sector": "", "Neighborhood": "", "District": "", "City": "Tilton", "MetroArea": "", "Subregion": "Belknap County", "Region": "New Hampshire", "RegionAbbr": "NH", "Territory": "", "Postal": "03276", "PostalExt": "", "CntryName": "United States", "CountryCode": "USA", "OBJECTID": 1}}, {"geometry": {"x": -71.50624850369367, "y": 43.435388250944946, "spatialReference": {"wkid": 4326, "latestWkid": 4326}}, "attributes": {"Match_addr": "3 Meadow Ln, Belmont, New Hampshire, 03220", "LongLabel": "3 Meadow Ln, Belmont, NH, 03220, USA", "ShortLabel": "3 Meadow Ln", "Addr_type": "PointAddress", "Type": "", "PlaceName": "", "AddNum": "3", "Address": "3 Meadow Ln", "Block": "", "Sector": "", "Neighborhood": "", "District": "", "City": "Belmont", "MetroArea": "", "Subregion": "Belknap County", "Region": "New Hampshire", "RegionAbbr": "NH", "Territory": "", "Postal": "03220", "PostalExt": "4407", "CntryName": "United States", "CountryCode": "USA", "OBJECTID": 2}}], "objectIdFieldName": "OBJECTID", "spatialReference": {"latestWkid": 4326}, "geometryType": "esriGeometryPoint", "fields": [{"name": "Match_addr", "alias": "Match_addr", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "LongLabel", "alias": "LongLabel", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "ShortLabel", "alias": "ShortLabel", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "Addr_type", "alias": "Addr_type", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "Type", "alias": "Type", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "PlaceName", "alias": "PlaceName", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "AddNum", "alias": "AddNum", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "Address", "alias": "Address", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "Block", "alias": "Block", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "Sector", "alias": "Sector", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "Neighborhood", "alias": "Neighborhood", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "District", "alias": "District", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "City", "alias": "City", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "MetroArea", "alias": "MetroArea", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "Subregion", "alias": "Subregion", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "Region", "alias": "Region", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "RegionAbbr", "alias": "RegionAbbr", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "Territory", "alias": "Territory", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "Postal", "alias": "Postal", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "PostalExt", "alias": "PostalExt", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "CntryName", "alias": "CntryName", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "CountryCode", "alias": "CountryCode", "type": "esriFieldTypeString", "sqlType": "sqlTypeOther"}, {"name": "OBJECTID", "type": "esriFieldTypeOID", "alias": "OBJECTID", "sqlType": "sqlTypeOther"}]}

# %%
# destinations_sdf['Latitude'][0]
# destinations_sdf['Longitude'][0]

# %%
rev_geocode = []
origin_features = []

# destinations_sdf['Latitude'][0]
# destinations_sdf['Longitude'][0]

for i in range(len(destinations_sdf)):
    reverse_geocode = geocoding.reverse_geocode({"x": destinations_sdf['Longitude'][0], 
                                             "y": destinations_sdf['Latitude'][0]})
    rev_geocode.append(reverse_geocode['address']['Match_addr'])
    
    origin_feature = Feature(geometry=reverse_geocode['location'], 
                           attributes=reverse_geocode['address'])
    origin_features.append(origin_feature)

print(origin_features)
print('\n')

origin_fset = FeatureSet(origin_features, geometry_type='esriGeometryPoint',
                          spatial_reference={'latestWkid': 4326})
    
origin_fset
# Out:
# [{"geometry": {"x": -71.55026815080141, "y": 43.48081594779246, "spatialReference": {"wkid": 4326, "latestWkid": 4326}}, "attributes": {"Match_addr": "225-227 Lancaster Hill Rd, Tilton, New Hampshire, 03276", "LongLabel": "225-227 Lancaster Hill Rd, Tilton, NH, 03276, USA", "ShortLabel": "225-227 Lancaster Hill Rd", "Addr_type": "StreetAddress", "Type": "", "PlaceName": "", "AddNum": "225", "Address": "225 Lancaster Hill Rd", "Block": "", "Sector": "", "Neighborhood": "", "District": "", "City": "Tilton", "MetroArea": "", "Subregion": "Belknap County", "Region": "New Hampshire", "RegionAbbr": "NH", "Territory": "", "Postal": "03276", "PostalExt": "", "CntryName": "United States", "CountryCode": "USA"}}, {"geometry": {"x": -71.55026815080141, "y": 43.48081594779246, "spatialReference": {"wkid": 4326, "latestWkid": 4326}}, "attributes": {"Match_addr": "225-227 Lancaster Hill Rd, Tilton, New Hampshire, 03276", "LongLabel": "225-227 Lancaster Hill Rd, Tilton, NH, 03276, USA", "ShortLabel": "225-227 Lancaster Hill Rd", "Addr_type": "StreetAddress", "Type": "", "PlaceName": "", "AddNum": "225", "Address": "225 Lancaster Hill Rd", "Block": "", "Sector": "", "Neighborhood": "", "District": "", "City": "Tilton", "MetroArea": "", "Subregion": "Belknap County", "Region": "New Hampshire", "RegionAbbr": "NH", "Territory": "", "Postal": "03276", "PostalExt": "", "CntryName": "United States", "CountryCode": "USA"}}, {"geometry": {"x": -71.55026815080141, "y": 43.48081594779246, "spatialReference": {"wkid": 4326, "latestWkid": 4326}}, "attributes": {"Match_addr": "225-227 Lancaster Hill Rd, Tilton, New Hampshire, 03276", "LongLabel": "225-227 Lancaster Hill Rd, Tilton, NH, 03276, USA", "ShortLabel": "225-227 Lancaster Hill Rd", "Addr_type": "StreetAddress", "Type": "", "PlaceName": "", "AddNum": "225", "Address": "225 Lancaster Hill Rd", "Block": "", "Sector": "", "Neighborhood": "", "District": "", "City": "Tilton", "MetroArea": "", "Subregion": "Belknap County", "Region": "New Hampshire", "RegionAbbr": "NH", "Territory": "", "Postal": "03276", "PostalExt": "", "CntryName": "United States", "CountryCode": "USA"}}, {"geometry": {"x": -71.55026815080141, "y": 43.48081594779246, "spatialReference": {"wkid": 4326, "latestWkid": 4326}}, "attributes": {"Match_addr": "225-227 Lancaster Hill Rd, Tilton, New Hampshire, 03276", "LongLabel": "225-227 Lancaster Hill Rd, Tilton, NH, 03276, USA", "ShortLabel": "225-227 Lancaster Hill Rd", "Addr_type": "StreetAddress", "Type": "", "PlaceName": "", "AddNum": "225", "Address": "225 Lancaster Hill Rd", "Block": "", "Sector": "", "Neighborhood": "", "District": "", "City": "Tilton", "MetroArea": "", "Subregion": "Belknap County", "Region": "New Hampshire", "RegionAbbr": "NH", "Territory": "", "Postal": "03276", "PostalExt": "", "CntryName": "United States", "CountryCode": "USA"}}, {"geometry": {"x": -71.55026815080141, "y": 43.48081594779246, "spatialReference": {"wkid": 4326, "latestWkid": 4326}}, "attributes": {"Match_addr": "225-227 Lancaster Hill Rd, Tilton, New Hampshire, 03276", "LongLabel": "225-227 Lancaster Hill Rd, Tilton, NH, 03276, USA", "ShortLabel": "225-227 Lancaster Hill Rd", "Addr_type": "StreetAddress", "Type": "", "PlaceName": "", "AddNum": "225", "Address": "225 Lancaster Hill Rd", "Block": "", "Sector": "", "Neighborhood": "", "District": "", "City": "Tilton", "MetroArea": "", "Subregion": "Belknap County", "Region": "New Hampshire", "RegionAbbr": "NH", "Territory": "", "Postal": "03276", "PostalExt": "", "CntryName": "United States", "CountryCode": "USA"}}, {"geometry": {"x": -71.55026815080141, "y": 43.48081594779246, "spatialReference": {"wkid": 4326, "latestWkid": 4326}}, "attributes": {"Match_addr": "225-227 Lancaster Hill Rd, Tilton, New Hampshire, 03276", "LongLabel": "225-227 Lancaster Hill Rd, Tilton, NH, 03276, USA", "ShortLabel": "225-227 Lancaster Hill Rd", "Addr_type": "StreetAddress", "Type": "", "PlaceName": "", "AddNum": "225", "Address": "225 Lancaster Hill Rd", "Block": " ...
# <FeatureSet> 123 features

# %%
dest.insert(0,'ADDRESS',rev_geocode)
dest
# Out:
#                                                ADDRESS  OBJECTID  \
# 0    225-227 Lancaster Hill Rd, Tilton, New Hampshi...         1
# 1    225-227 Lancaster Hill Rd, Tilton, New Hampshi...         2
# 2    225-227 Lancaster Hill Rd, Tilton, New Hampshi...         3
# 3    225-227 Lancaster Hill Rd, Tilton, New Hampshi...         4
# 4    225-227 Lancaster Hill Rd, Tilton, New Hampshi...         5
# ..                                                 ...       ...
# 118  225-227 Lancaster Hill Rd, Tilton, New Hampshi...       119
# 119  225-227 Lancaster Hill Rd, Tilton, New Hampshi...       120
# 120  225-227 Lancaster Hill Rd, Tilton, New Hampshi...       121
# 121  225-227 Lancaster Hill Rd, Tilton, New Hampshi...       122
# 122  225-227 Lancaster Hill Rd, Tilton, New Hampshi...       123
#
#                                                  SHAPE
# 0    {"x": -7964909.474918244, "y": 5385319.1230474...
# 1    {"x": -7960108.721342988, "y": 5378504.2357500...
# 2    {"x": -7966935.643622118, "y": 5411109.5689599...
# 3    {"x": -7939651.980886165, "y": 5396701.6072392...
# 4    {"x": -7963249.366946323, "y": 5407198.6218585...
# ..                                                 ...
# 118  {"x": -8055046.161214717, "y": 5393042.8753068...
# 119  {"x": -8027664.37115518, "y": 5360001.72410986...
# 120  {"x": -8051707.147086771, "y": 5355683.4923355...
# 121  {"x": -8037834.850348912, "y": 5360330.9782417...
# 122  {"x": -8025131.073530523, "y": 5376138.6213152...
#
# [123 rows x 3 columns]

# %%
destinations_sdf = dest.iloc[0:3,:]
destinations_sdf
# Out:
#                                              ADDRESS  OBJECTID  \
# 0  225-227 Lancaster Hill Rd, Tilton, New Hampshi...         1
# 1  225-227 Lancaster Hill Rd, Tilton, New Hampshi...         2
# 2  225-227 Lancaster Hill Rd, Tilton, New Hampshi...         3
#
#                                                SHAPE
# 0  {"x": -7964909.474918244, "y": 5385319.1230474...
# 1  {"x": -7960108.721342988, "y": 5378504.2357500...
# 2  {"x": -7966935.643622118, "y": 5411109.5689599...

# %%
# destinations_sdf_2 = dest.iloc[3:6,:]
# destinations_sdf_2 

# origin_fset = FeatureSet(destinations_sdf_2 , geometry_type='esriGeometryPoint',
#                           spatial_reference={'latestWkid': 4326})

# origin_fset

# %%
destinations_fset = destinations_sdf.spatial.to_featureset()
print(destinations_fset)
# Out:
# {"features": [{"geometry": {"x": -7964909.474918244, "y": 5385319.123047448, "spatialReference": {"wkid": 102100, "latestWkid": 3857}}, "attributes": {"ADDRESS": "225-227 Lancaster Hill Rd, Tilton, New Hampshire, 03276", "OBJECTID": 1}}, {"geometry": {"x": -7960108.721342988, "y": 5378504.235750002, "spatialReference": {"wkid": 102100, "latestWkid": 3857}}, "attributes": {"ADDRESS": "225-227 Lancaster Hill Rd, Tilton, New Hampshire, 03276", "OBJECTID": 2}}, {"geometry": {"x": -7966935.643622118, "y": 5411109.568959956, "spatialReference": {"wkid": 102100, "latestWkid": 3857}}, "attributes": {"ADDRESS": "225-227 Lancaster Hill Rd, Tilton, New Hampshire, 03276", "OBJECTID": 3}}], "objectIdFieldName": "OBJECTID", "displayFieldName": "OBJECTID", "spatialReference": {"wkid": 102100, "latestWkid": 3857}, "geometryType": "esriGeometryPoint", "fields": [{"name": "OBJECTID", "type": "esriFieldTypeOID", "alias": "OBJECTID"}, {"name": "ADDRESS", "type": "esriFieldTypeString", "length": 55, "alias": "ADDRESS"}]}

# %%
# %%time
# solve OD cost matrix tool for the origns and destinations
from arcgis.network.analysis import generate_origin_destination_cost_matrix
results = generate_origin_destination_cost_matrix(origins= origin_fset, #origins_fc_latlong, 
                                                destinations= destinations_fset, #destinations_fs_address,
                                                origin_destination_line_shape='Straight Line')
print('Analysis succeeded? {}'.format(results.solve_succeeded))
# Out:
# Analysis succeeded? True
# Wall time: 23 s

# %%
od_df = results.output_origin_destination_lines.sdf
od_df
# Out:
#      ObjectID  DestinationRank  Total_Time  Total_Distance  OriginID  \
# 0           1                1    0.554522        0.252412         1
# 1           2                2   10.428848        8.025176         1
# 2           3                3   27.698819       29.668284         1
# 3           4                1    0.554522        0.252412         2
# 4           5                2   10.428848        8.025176         2
# ..        ...              ...         ...             ...       ...
# 364       365                2   10.428848        8.025176       122
# 365       366                3   27.698819       29.668284       122
# 366       367                1    0.554522        0.252412       123
# 367       368                2   10.428848        8.025176       123
# 368       369                3   27.698819       29.668284       123
#
#      OriginOID    OriginName  DestinationID  DestinationOID DestinationName  \
# 0            1    Location 1              1               1      Location 1
# 1            1    Location 1              2               2      Location 2
# 2            1    Location 1              3               3      Location 3
# 3            2    Location 2              1               1      Location 1
# 4            2    Location 2              2               2      Location 2
# ..         ...           ...            ...             ...             ...
# 364        122  Location 122              2               2      Location 2
# 365        122  Location 122              3               3      Location 3
# 366        123  Location 123              1               1      Location 1
# 367        123  Location 123              2               2      Location 2
# 368        123  Location 123              3               3      Location 3
#
#      Shape_Length                                              SHAPE
# 0        0.000868  {"paths": [[[-71.55026815099995, 43.4808159480...
# 1        0.062704  {"paths": [[[-71.55026815099995, 43.4808159480...
# 2        0.168011  {"paths": [[[-71.55026815099995, 43.4808159480...
# 3        0.000868  {"paths": [[[-71.55026815099995, 43.4808159480...
# 4        0.062704  {"paths": [[[-71.55026815099995, 43.4808159480...
# ..            ...                                                ...
# 364      0.062704  {"paths": [[[-71.55026815099995, 43.4808159480...
# 365      0.168011  {"paths": [[[-71.55026815099995, 43.4808159480...
# 366      0.000868  {"paths": [[[-71.55026815099995, 43.4808159480...
# 367      0.062704  {"paths": [[[-71.55026815099995, 43.4808159480...
# 368      0.168011  {"paths": [[[-71.55026815099995, 43.4808159480...
#
# [369 rows x 12 columns]

# %%
# filter only the required columns
od_df2 = od_df[['DestinationOID','OriginOID','Total_Distance','Total_Time']]

# user pivot_table
od_pivot = od_df2.pivot_table(index='OriginOID', columns='DestinationOID')
od_pivot
# Out:
#                Total_Distance                      Total_Time             \
# DestinationOID              1         2          3          1          2
# OriginOID
# 1                    0.252412  8.025176  29.668284   0.554522  10.428848
# 2                    0.252412  8.025176  29.668284   0.554522  10.428848
# 3                    0.252412  8.025176  29.668284   0.554522  10.428848
# 4                    0.252412  8.025176  29.668284   0.554522  10.428848
# 5                    0.252412  8.025176  29.668284   0.554522  10.428848
# ...                       ...       ...        ...        ...        ...
# 119                  0.252412  8.025176  29.668284   0.554522  10.428848
# 120                  0.252412  8.025176  29.668284   0.554522  10.428848
# 121                  0.252412  8.025176  29.668284   0.554522  10.428848
# 122                  0.252412  8.025176  29.668284   0.554522  10.428848
# 123                  0.252412  8.025176  29.668284   0.554522  10.428848
#
#
# DestinationOID          3
# OriginOID
# 1               27.698819
# 2               27.698819
# 3               27.698819
# 4               27.698819
# 5               27.698819
# ...                   ...
# 119             27.698819
# 120             27.698819
# 121             27.698819
# 122             27.698819
# 123             27.698819
#
# [123 rows x 6 columns]

# %%
od_pivot.to_csv('OD_Matrix.csv')

# %%
od_map = my_gis.map('New Hampshire')
od_map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-7f3f7a19-6f6a-4e41-abfe-fda25a2c4909"><img src=""></img></div>
# <div class="map-html-embed-preview-7f3f7a19-6f6a-4e41-abfe-fda25a2c4909"></div>

# %%
od_map.draw(results.output_origin_destination_lines)
od_map.draw(destinations_fset, symbol={"type": "esriSMS","style": "esriSMSSquare","color": [255,115,0,255], "size": 10})
od_map.draw(origin_fset, symbol={"type": "esriSMS","style": "esriSMSCircle","color": [76,115,0,255],"size": 8})
